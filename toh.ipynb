# %%
def tower_of_hanoi(n, A, C, B):  
    if n == 1:
        print(f"Move disk 1 from {A} to {C}")
        return

    tower_of_hanoi(n - 1, A, B, C)  
    print(f"Move disk {n} from {A} to {C}")  
    tower_of_hanoi(n - 1, B, C, A)  


tower_of_hanoi(10, 'A', 'C', 'B')
# Out:
# Move disk 1 from A to B
# Move disk 2 from A to C
# Move disk 1 from B to C
# Move disk 3 from A to B
# Move disk 1 from C to A
# Move disk 2 from C to B
# Move disk 1 from A to B
# Move disk 4 from A to C
# Move disk 1 from B to C
# Move disk 2 from B to A
# Move disk 1 from C to A
# Move disk 3 from B to C
# Move disk 1 from A to B
# Move disk 2 from A to C
# Move disk 1 from B to C
# Move disk 5 from A to B
# Move disk 1 from C to A
# Move disk 2 from C to B
# Move disk 1 from A to B
# Move disk 3 from C to A
# Move disk 1 from B to C
# Move disk 2 from B to A
# Move disk 1 from C to A
# Move disk 4 from C to B
# Move disk 1 from A to B
# Move disk 2 from A to C
# Move disk 1 from B to C
# Move disk 3 from A to B
# Move disk 1 from C to A
# Move disk 2 from C to B
# Move disk 1 from A to B
# Move disk 6 from A to C
# Move disk 1 from B to C
# Move disk 2 from B to A
# Move disk 1 from C to A
# Move disk 3 from B to C
# Move disk 1 from A to B
# Move disk 2 from A to C
# ...

# %%
class ArrayADT:
    def __init__(self, capacity):
        self.arr = [None] * capacity
        self.size = 0

    def insert(self, index, value):
        if self.size >= len(self.arr):
            raise Exception("Array full")
        for i in range(self.size, index, -1):
            self.arr[i] = self.arr[i-1]
        self.arr[index] = value
        self.size += 1

    def delete(self, index):
        for i in range(index, self.size - 1):
            self.arr[i] = self.arr[i+1]
        self.arr[self.size - 1] = None
        self.size -= 1

    def get(self, index):
        return self.arr[index]

# %%
a = ArrayADT(5)
a.insert(0, 10)
a.insert(1, 20)
a.insert(2, 30)
a.insert(1, 15)

print("Array after insertions:", a.arr[:a.size])  

a.delete(2)  
print("Array after deletion:", a.arr[:a.size])  

print("Element at index 1:", a.get(1))
# Out:
# Array after insertions: [10, 15, 20, 30]
# Array after deletion: [10, 15, 30]
# Element at index 1: 15
